# %% [markdown]
# ## Gilette Ad Notebook

# %%
#This is how you install python packages into Jupyter Notebook
#The package we will be using to interface with Twitter is Python-Twitter
# !pip install python-twitter

# %%
pip
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more informations on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
#Importing packages and libraries, these packages are already downloaded on my computer so I do not have to install them
#like in the previous cell. You can do these for all packages you have downloaded and want to use in your notebook

#It's a good practice to import numerous libraries, in case you might need it later in your first or second cell

import twitter #<- from the python-twitter package. A Python wrapper around the Twitter API. 
#This library provides a pure Python interface for the Twitter API. It works with Python versions from 2.7+ and Python 3.
#Twitter exposes a web services API and this library is intended to make it even easier for Python programmers to use.

#Further documentation: **https://github.com/bear/python-twitter**

import re #<--from the regular expression *re* package. A regular expression is a special sequence of characters that 
#helps you match or find other strings or sets of strings, using a specialized syntax held in a pattern. 

#Further documentation: **https://docs.python.org/3/library/re.html**

import string #<- from the string package that useds common string operations such as lowercasing or uppercasing string

#Further documentation: **https://docs.python.org/3/library/string.html** 

import nltk #<- #from the NLTK package. NLTK -- the Natural Language Toolkit -- is a suite of open source Python modules,
#data sets, and tutorials supporting research and development in Natural Language Processing

#Further documentation: http://www.nltk.org/ &&  https://www.nltk.org/book/ch01.html

#Tokenization is the act of breaking up a sequence of strings into pieces such as words, keywords, phrases, symbols 
#and other elements called tokens.

from nltk.tokenize import word_tokenize #tokenizes and breaks down tokens into words
from nltk.corpus import stopwords #takes out unneccessary stopwords, but decided not to use it this time
from nltk.stem import WordNetLemmatizer #lemmas are the canonical form of a set of words. The form of a word that 
#appears at the beginning of a dictionary or glossary entry. For example run, ran, and running all have the semantic
#representation of run
from nltk.tokenize import sent_tokenize #tokenizes and breaks down tokens into sentences *what we will be using*

# %%
#When you use python-twitter or any other twitter library, you must verify your Twitter API credentials  to get access
#Everyone with a developer account on Twitter is given a set of 4 keys consumer key & secret, & token_key & token_secret
#Feel free to use your own credentials

#Find out your credentials: https://developer.twitter.com/en/docs/basics/authentication/guides/access-tokens.html

api = twitter.Api(consumer_key="   ", #plug in your keys
  consumer_secret="  ",
  access_token_key="  ",
  access_token_secret="   ")

# %%
#Verifying credentials 
#As you can see in my profile snippet, my last status was on Mon August 13th sharing my article - yikes!
print(api.VerifyCredentials())
# Out:
# {"created_at": "Wed Jan 24 01:06:51 +0000 2018", "description": "Student. Writer & Musician. https://t.co/YMQYL4Aery", "favourites_count": 3, "friends_count": 12, "id": 955970115576717312, "id_str": "955970115576717312", "lang": "en", "name": "Chantel Diaz", "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "profile_image_url": "http://pbs.twimg.com/profile_images/1020805483962118145/v-41dsY4_normal.jpg", "profile_image_url_https": "https://pbs.twimg.com/profile_images/1020805483962118145/v-41dsY4_normal.jpg", "profile_link_color": "F58EA8", "profile_sidebar_border_color": "000000", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "screen_name": "chmd_", "status": {"created_at": "Mon Aug 13 15:06:54 +0000 2018", "favorite_count": 1, "id": 1029021483434160128, "id_str": "1029021483434160128", "lang": "en", "quoted_status_id": 1027542514356637696, "quoted_status_id_str": "1027542514356637696", "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "text": "Read my article on GIGsoup #gigsoup #cursive #vitriola https://t.co/UzToxXU0Tl"}, "statuses_count": 7}

# %%
#As always it's important to read the documentation of each programming language and each package you use

#In this case, python-twitter allows you to retrieve statuses by handle using GetUserTimeline function

#You assign "statuses" which retrieves a list back of 100 Gillette's most recent tweets. 
#When printing a list, you must iterate through the list to get all the elements in it.
#This is represented in s.text FOR s in statuses. This is called a list comprehension

#Read more about it here: https://docs.python.org/3/tutorial/datastructures.html#list-comprehensions

#Let's see what the people at Gillette are saying first and compare it to the public opinion
statuses = api.GetUserTimeline(screen_name="Gillette", count=100)
print([s.text for s in statuses])
# Out:
# ["@TheGreekSimba We're so happy to hear that, Crayton. We believe in the best in men and want to use our platform to… https://t.co/TXYmX6F0aM", '@docrn1 Thank you! We appreciate your support.', "@Htigy55t We're so glad you liked it, Aviva. Men everywhere are already working to re-write the rules on what it lo… https://t.co/QyHcEfoJ1s", "@JimmyMorabito We appreciate your kind words, Jimmy. We're happy to hear you liked our Pure Shave Gel, we'll contin… https://t.co/s1FRkd2o1b", '@herb_betts Thank you for the support!', '@RSullPhoto We appreciate the support! Fusion 5 makes for a great shave!', '@tracyre We appreciate your support, Tracy.  Thank you for joining us in this important conversation!', '@richiedelapenha We greatly appreciate your support and kind words, Richard. As a brand that encourages men to be t… https://t.co/gELf2fpefs', '@InsidetheNCAA Congrats @Shaquemgriffin! This award is well deserved, keep up the hard work and dedication.', "@taytayallday92 We truly appreciate the support from you and your dad, Tay. It's great to hear you both liked it. W… https://t.co/R6pY38OMU6", '@RobynNormandale We appreciate your kind words, Robyn. As a brand that has served men for 115+ years, we believe th… https://t.co/Hc4uopxV7t', "@darbybaham We're so happy you liked it, Darby. We're committed to using our marketing to advance a more modern, po… https://t.co/YdpXthFbr5", "@weatheredford We're happy to be able to provide you with a smooth and quality shave, Timothy. It's nice to receive… https://t.co/haKKRYrsIb", '@neelp91 We greatly appreciate your kind words and support, Neel.  As a brand that has been an essential part of ma… https://t.co/tL9Y4SqudK', "@RuthTweetX We're glad you liked it, Ruth. As a brand that has served men for 115+ years, we believe that the optim… https://t.co/j5E2nCoAfY", "@SillyNekoBoi We're happy to hear you liked the ad and chose us for your grooming routine. We'll continue to provid… https://t.co/3QFAgPiEJG", "@BarriMedia We're glad we were able to provide you with a quality shave, Barry. It's great to have you on our team! Thanks for the support.", "@BeliefBeat We're so glad you liked it, Nicole. We appreciate your support and kind words!", "@JayJimen We appreciate your kind words, Jay. We're happy to hear you liked it, thanks for the support!", "@Economics_2018 Thank you, we're glad you liked it! Men everywhere are already working to re-write the rules on wha… https://t.co/nMAfrCXpys", '@zwhit Thank you, Zack. We believe in the best in men and want to use our platform to show men doing great things.… https://t.co/AdWewws8Gm', "@esmavibe Thanks, Esma! This is an important conversation to have, we're committed to using our marketing to advanc… https://t.co/faX4NPogWY", "@debbiedeas Thank you, Debbie! We appreciate your kind words and are glad you liked it.  As a brand that's been an… https://t.co/AegYtqbEux", "@hayleylxnn We're glad you liked it and understand our message. Our priority today and always is to be current with… https://t.co/3GGV1potAW", '@kridge14 We greatly appreciate your kind words! As a brand that encourages men to be their best, we have a respons… https://t.co/qxfsONeJ52', '@nancystaack Thank you, Nancy.  We appreciate the support.', '@MissCain5 We appreciate your support! Thank you!', '@skypeople63135 Thank you for the support!', '@fakesmilelovato We appreciate your support! We think this is an issue that needs to be talked about, thank you for… https://t.co/egRibtv4dS', '@sllertzman Thank you, Sarah.  We appreciate your kind comments and support in this.', '@ScoRoc Doing what is right is exactly right!  Thank you, Scott!', '@penelopejune11 Thank you for your support, we appreciate that.', '@JewartSheilah Thank you for backing us!', '@irishonthepiss Thank you!', '@rainescud Thank you for the support! We appreciate it!', '@MadamElle7 Thank you for your support!', '@rajeevpillay96 Thank you for the support!', '@hoodlynn37 We appreciate your comments, Linda.  We agree!', '@christopher9 ...

# %%
#Seems like people in Gillette are embracing their new campaign quite positively
#Before getting tweets, lets use a emoji stirp function from stack overflow to see if we can take them out

#This is where understanding the re package and its libraries are important. 
#Emojis are based on unicode characters, so you have to know the syntax to strip them

# http://stackoverflow.com/a/13752628/6762004
RE_EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE) #this compiles a pretty good range of emojis

#Full emoji list: https://unicode.org/emoji/charts/full-emoji-list.html

def strip_emoji(text): #def defines a new function you create, you can call it anything as long as you pass an argument in it
    return RE_EMOJI.sub(r'', text) #that function will then return the desired output, which is to substitute them as blanks

#Seems like it'll work pretty well

print(strip_emoji('🙄🤔'))

# %%
#Here we are putting it ALL together

#Another function is Python-Twitter is to GetSearch, which grabs hashtags or keywords of your choice. This is what we will
#be using for our purposes. Here we are finding #gillette, getting english only "en" tweets, and about 100 of them for now

search = api.GetSearch("#gillette", lang="en",count=100) #search is a list of tweets, similar to last time

#However here we need to create a FOR loop in our list to iterate through the elements to do the other tasks we don't want
#to do ourselves :D, such as cleaning! Again, here is where NLTK + regular expressions + the string module come into play

#Read more about for loops: https://www.w3schools.com/python/python_for_loops.asp

for t in search: #t could be literally called anything like x, since its calling the list element of search
    tweets = t.text.lower() #defining tweets as a new list that lowers all the text to lowercase using string module
    tweets = re.sub(r"http\S+", "", tweets) #using regular expressions to replace more symbols for blanks
    tweets = tweets.replace("…","") #The replace() method returns a copy of the string where all occurrences 
    #of a substring is replaced with another substring. In this case ... with blanks
    tweets = strip_emoji(tweets) #calling the strip_emoji function on the tweets
    sentences = sent_tokenize(tweets.replace('\n',' ')) #tokenizes tweets into sentences, replaces the line break '\n' with blank
    clean_words = [word for word in sentences if word not in set(string.punctuation)] #another list comprehension in the 
    #sentences list that will clean out the words with string punctuation and return clean_words
    characters_to_remove = ["''",'``','...', "'rt",'"rt', ','] #creating another list with other characters we want to remove like quotes
    #and more. put things in double quotes when a quote is used in the characters removed
    clean_words = [word for word in clean_words if word not in set(characters_to_remove)] #applying that list to our clean_words
    #to take out the characters we want to remove, characters_to_remove can be further added as well
    characters_to_remove2 = [word for word in clean_words if any(letter in sentences for letter in '\\')] #taking out other slashes
    clean_words = [word for word in clean_words if word not in set(characters_to_remove2)] #again applying that list
    print(clean_words) #print to see the final output of your new clean_words list from the original search
# Out:
# ['we’re told that there is a crisis of masculinity.', 'from #metoo to #gillette - something isn’t working.', 'garrett j wh']
# ["@basedpoland @crusaderkeif a country run by women who don't approve of masculinity.", '#gillette #procterandgamble']
# ['nervous to apply for a job like "food champion" at border foods?', "apply even if you're not a 100% match.", 'you might b']
# ['rt @cbckidsnews: last month, #gillette released a controversial ad campaign calling on men to "be better" for the men of tomorrow.', 'but what']
# ["don't be shy.", 'score a job like "cross utilized agent - gcc" at skywest airlines by asking for referrals.', "it's a gre"]
# ['wonder what #gillette will do about their sponsorship of the #pats stadium?', '#thebestmencanbe #robertkraft #podcast']
# ["dear massachusetts officials: any plans for a parade to honor the brutalized women who cater to robert kraft's sexu"]
# ['interested in a job in #gillette, wy?', 'this could be a great fit.', 'click the link in our bio to apply: floorhand-well']
# ["rt @thelifesway: shop #anythingyoucanimagine @takealot  it's going to be a clean shave now!", '#thelifesway #photoyatra']
# ['rt @chriswillx: we’re told that there is a crisis of masculinity.', 'from #metoo to #gillette - something isn’t working.', 'garrett j white has']
# ['this job is now open at spencer fluid power, inc in #gillette, wy.', 'follow us and turn on mobile alerts to hear abou']
# ['rt @chriswillx: we’re told that there is a crisis of masculinity.', 'from #metoo to #gillette - something isn’t working.', 'garrett j white has']
# ['rt @chriswillx: we’re told that there is a crisis of masculinity.', 'from #metoo to #gillette - something isn’t working.', 'garrett j white has']
# ['rt @chriswillx: we’re told that there is a crisis of masculinity.', 'from #metoo to #gillette - something isn’t working.', 'garrett j white has']
# ['rt @chriswillx: we’re told that there is a crisis of masculinity.', 'from #metoo to #gillette - something isn’t working.', 'garrett j white has']
# ['rt @chriswillx: we’re told that there is a crisis of masculinity.', 'from #metoo to #gillette - something isn’t working.', 'garrett j white has']
# ['@realjameswoods two and a half #gillette']
# ['it’s not a question of men or women, it’s a question of #education #gillette get back to school to improve it.', 'paro']
# ['check out this amazon deal: gillette mach3 men’s razor blade refills, 15 count #gillette #mach3 #rezorbladerefills']
# ['rt @livingroomconvo: join us to discuss the controversial gillette ad, “the best men can be” february 28, 2019 @ 1:30pm-2:00pm eastern/10:3']
# ["rt @raphael_the_pt: masculinity isn't toxic, lack of it is.", 'be polite, be respectful, be a gentleman.', 'be a man.', '#gillette #boyswillbeboys #']
# ['rt @chriswillx: we’re told that there is a crisis of masculinity.', 'from #metoo to #gillette - something isn’t working.', 'garrett j white has']
# ['we’re told that there is a crisis of masculinity.', 'from #metoo to #gillette - something isn’t working.', 'garrett j wh']
# ["rt @pkzac222: vintage gillette super-109 p-2 1970 adjustable razor safety razor men's grooming #gillette"]
# ['@themarkpantano next #gillette commercial talent for sure #smdh \u200d♂️']
# ['join us to discuss the controversial gillette ad, “the best men can be” february 28, 2019 @ 1:30pm-2:00pm eastern/1']
# ['check out gillette venus silk expert ipl 3001 intense pulsed light body hair removal #gillette  via @ebay']
# ['rt @internationalm: toxic feminity????', "it's your turn, ladies.", 'own up to this shit.', '#metoo #women #men #feminism #masculinity #gillette #fe']
# ['rt @tforceblun: jussie smollett deserves every bit of this!!', '#jussiesmoletthoax #jussiesmollet #gillette #beta #ho']
# ['rt @egardwatchco: our video response to gillette.', "it's time for society to start celebrating each other.", 'not tearing each other down.', '#wes']
# ['rt @majinbuuradley: #gillette #gillettead toxic men: "people these days are way too sensitive"  gillette: "maybe you should try being a bet']
# ['@realtealswan teal swan  #metoo #gillette #toxicmasculinity']
# ['rt @egardwatchco: our video response to gillette.', "it's time for society to start celebrating each other.", 'not tearing each other down.', '#wes']
# ["the gay #gillette ad was like 20 news cycles ago, but i'm retweeting this response to it from @egardwatchco again j"]
# ['rt @riky_76: a nice trip to the oriental mystery this morning.', '#sotd #tfs #tcheonfungsing #mingshi #omegabrush #gillette #slimtwist #nivea']
# ['rt @tornadonewslink: dumb and dumber: #theresamay and #amberrudd suppress #westminster child abuse documents for national security reasons']
# ['stock up on shampoo and razors with this amazon gold box deal  #personalcare #gillette #oldspice #pantene #amazon']
# ['#gillette advert gets used as example.', '#qanda']
# ['rt @pennyred: loving the new #gillette advert....']
# ['#india stocks: footwear #relaxo +1.8%.', 'fmcg #gillette -1.4%.', 'power #kalpataru +4.9%.', 'bearings #nrb +5.8%.', 'infra']
# ["price dropped: 27.05% ($8.10) - gillette fusion proshield men's razor blade refills, 8 count, mens razors / blades"]
# ['rt @riky_76: a nice trip to the oriental mystery this morning.', '#sotd #tfs #tcheonfungsing #mingshi #omegabrush #gillette #slimtwist #nivea']
# ['check out 100 gillette platinium &amp; polsilver super iridium double edge razor blades #gillette  via @ebay']
# ["@gillette #gillette #fuckthis #attention my dislike is still there so i have no idea what you're talking about people"]
# ['@andrewklavan #oscarssogay #hollywoodsogay #leftsogay #democratssogay #gayllette #gillette #mainstreamsogay']
# ['a nice trip to the oriental mystery this morning.', '#sotd #tfs #tcheonfungsing #mingshi #omegabrush #gillette']
# ['rt @biggobble: 10 years in the life of top 15 #global brands  #amazon #bmw #brandvalue #branding #brands #cisco #coc']
# ['@gadsaad #gillette says these men don’t exist']
# ['@washtimes @gillette is this the best a man can be?', '#gillette #thebestmencanbe']
# ['well done @nike for nailing it with your #oscars ad on ‘crazy’ female #athletes ft @serenawilliams showing']
# ['#gillette...you should pay attention to #nike when you approach gender equality #oscars']
# ['10 years in the life of top 15 #global brands  #amazon #bmw #brandvalue #branding #brands']
# ['rt @grumpyskeletor: this new advert from #gillette is an absolute outrage.', 'thanks for constantly reminding me i have no skin on my face,']
# ["straight up girls that talk about toxic masculinity and don't shave look like to this, get a razor and grow up you"]
# ["we're hiring in #gillette, wy!", 'click the link in our bio to apply to this job and more: multi-unit wireless manager']
# ['rt @burdekinassoc: #thebestamancanget - what do you think of the new #gillette ad campaign?']
# ['rt @rikwalters: great animated #video shows top 15 best global brands rankings 2000 - 2018 -  what trends do you see?']
# ['rt @ethica11y_vegan:  19 top cosmetics brands to end global animal testing  #crueltyfree   #olay #pantene #head_and_shoulders #gillette']
# ['boys will be boys #gillette']
# ['#thebestamancanget - what do you think of the new #gillette ad campaign?']
# ['rt @baenesh: if you think #masculinity is under attack because people oppose domineering, #bullying, bigoted, controlling behavior, then th']
# ['where’s #gillette when you need them?']
# ['rt @grumpyskeletor: this new advert from #gillette is an absolute outrage.', 'thanks for constantly reminding me i have no skin on my face,']
# ['#gillette #minority #minorities  #oppression #gay #transgender  i found some unjustifiably anti-#lgbt #toxic']
# ['the lad on the gillette advert is just fit, i need to find out who he is so i can stalk him  #gillette #gillettead']
# ['check out gillette altraplus razor with lubrastrip, 10 count, mens razors / blades #gillette  via @ebay']
# ['hot!free gillette venus razor!', 'click here▶️▶️  #freebies #free #freestuff #freeproducts']
# ['love this ad:  we believe: the best men can be | gillette (short film)  via @youtube #gillette']
# ['#nokia9 the best a dork can get #gillette']
# ['@concettina16 nothing brings out a woman’s disgust &amp; disinterest quicker than a man showing feelings.', 'look no furt']
# ['rt @baenesh: if you think #masculinity is under attack because people oppose domineering, #bullying, bigoted, controlling behavior, then th']
# ['can you recommend anyone for this #skilledtrade job in #gillette, wy?', 'click the link in our bio to see it and more.']
# ['family and friends happy hour: buy 3 get the 4th free monday-thursday  gillette 7-9pm summit 4-6pm  freeze on']
# ['if you think #masculinity is under attack because people oppose domineering, #bullying, bigoted, controlling behavi']
# ['rt @lamerafeli: my exact thought when i read all those negative comments from men.', 'who buys your razors anyway, dude???', '#gillette']
# ['did anyone from #gillette tell @patriots owner robert kraft he can #dobetter than $79 rub and tugs?', '#patriotway']
# ['rt @vatuttobene: #sotd good sunday you all’ friends !', 'an extra classic shave today with mini #gillette #tech travel edition ( a little b']
# ['rt @loomiassistant: controversy and tapping into current social (controversial) trends is such a powerful way for big brands to align with']
# ['controversy and tapping into current social (controversial) trends is such a powerful way for big brands to align w']
# ['rt @tomleykis: hey @gillette!', "you paid $120 million to name this guy's stadium @gillettestadium after yourself.", 'is this what you meant by "']
# ['#sotd good sunday you all’ friends !', 'an extra classic shave today with mini #gillette #tech travel edition ( a l']
# ['jussie smollett deserves every bit of this!!', '#jussiesmoletthoax #jussiesmollet #gillette']
# ['rt @mrdanwalker: just watched the #gillette advert.', 'not entirely sure why so many people are furious about it.', 'it’s tremendously corny in p']
# ['rt @obianuju: little brother rushes in to “save” his big sis.', 'very very cute!', 'the first time i saw this i wanted to say “boys will be boy']
# ["#tomilahren: releasing a man-bashing ad eg #gillette's #webelieve won't correct sick men.", 'prof. #jordanpeterson:']
# ['rt @mgtowfrank: someone made their own #gillettead video, but made it about toxic femininity instead.', 'youtube removed the video.', 'who knew']
# ['rt @mgtowfrank: someone made their own #gillettead video, but made it about toxic femininity instead.', 'youtube removed the video.', 'who knew']
# ['@trisresists @mcspocky @spockresists #unfilteredpictureofmichaelobama  barack changed its name to michelle        n']
# ['rt @tomleykis: hey @gillette!', "you paid $120 million to name this guy's stadium @gillettestadium after yourself.", 'is this what you meant by "']
# ['looking to score a job at general electric?', "you're in luck.", 'click the link in our bio for the job description and i']
# ['rt @godgotusbelieve: @fulleffectmaga @sahaisleykelly @lalaviealoha @deequi1 @finy06 @wileywonka59 @_iamanita_d @drshayphd @sherryodell16 @v']
# ["personally since i've been using quattro instead of #gillette (overpriced junk) i've found it's a better razor at a"]
# ['rt @egardwatchco: our video response to gillette.', "it's time for society to start celebrating each other.", 'not tearing each other down.', '#wes']
# ['i still wont buy #gillette products.']
# ['basic energy services is hiring in #gillette, wy!', 'read about our latest #transportation job opening via the link in']
# ['want to work at basic energy services?', "we're hiring in #gillette, wy!", 'click for details:  #labor']
# ['rt @healtha20333324:  via @youtube gillette razors mach 3 review-gillette razor comparison: mach 3 turbo vs fusion 5']
# ['rt @chsommers: here is the video #gillette should have made.', '“what is a man?”']
# ['rt @ledzeplover: just made this  #jussiesmolletthoax #jussiesmollett #gillette']
# ['icymi: find out what the all-new hypocrisy news is all about!', 'the latest hypocrisies from #lisaborders of #timesup,']

# %%
#Similar concept here:
search = api.GetSearch("gillette", lang='en', count=100)
for t in search:
    tweets = t.text.lower()
    tweets = re.sub(r"http\S+", "", tweets)
    tweets = tweets.replace("…","")
    tweets = strip_emoji(tweets)
    sentences = sent_tokenize(tweets.replace('\n',' '))
    clean_words = [word for word in sentences if word not in set(string.punctuation)]
    characters_to_remove = ["''",'``','...']
    clean_words = [word for word in clean_words if word not in set(characters_to_remove)]
    characters_to_remove2 = [word for word in clean_words if any(letter in sentences for letter in '\\')]
    clean_words = [word for word in clean_words if word not in set(characters_to_remove2)]
    print(clean_words)
# Out:
# ['when the krafts raised the gillette stadium sign two years ago to make room for a 5th super bowl banner, they had t']
# ['the  sheds his coat.', 'tb12 stops by @gillette headquarters in boston for a fresh, post-super bowl shave.']
# ["turns out almost everyone loved that 'controversial' gillette ad about toxic masculinity․"]
# ['@coachvass @suffragentleman @realamberheard @piersmorgan @gillette why is that?']
# ['don\'t show this "toxic masculinity" to the "gillette democratic girlies in white" club !!!', 'ahahahah !!!!!!']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @gyakutennomeg: two little boys roughhousing?', 'labeled "toxic masculinity" by gillette.', 'little black girl punching a little white boy in']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['@gillette nothing says customer service like ignoring someone and then banishing them to on hold.']
# ['rt @mrewanmorrison: "metropolis" was a plan for a utopian future city (1894) by king camp gillette (1855-1932) inventor of the safety razor']
# ['rt @gyakutennomeg: two little boys roughhousing?', 'labeled "toxic masculinity" by gillette.', 'little black girl punching a little white boy in']
# ["rt @takedownmras: warwick marsh, the men's rights activist who didn't want gay men to be able marry / thinks conversion therapy works, not"]
# ['gillette world club challenge programme leeds rhinos v melbourne storm 2010   £2.00 (0 bids)']
# ['rt @yalebroads: “supporting women and calling for a safer world for all does not make you less of a man.', 'it makes you a better person.” @cu']
# ['rt @spidervesre: this is how you use your brand.', 'this is how you engage with your audience.', 'gillette being aware of mostly having a male au']
# ['rt @blazetv: "i want a man to be masculine.', 'i want someone to open the door for me!"', 'why was gillette willing to risk 50% of their client']
# ['@__friedrice @softly_sighing2 no, i don’t.. i don’t think it’s harmful to teach “little boys” that there’s an issue']
# ['@rroaded @uksurvivorjohn @proctergamble @gillette you think gillette will do a video on toxic femininity?', 'women mak']
# ['rt @designationsix: these are @foxnews sponsors.', 'they are tagged so they will be notified for each like/retweet/comment @keurig @nestle @ol']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @gemma_brett: that gillette ad though right, so offensive']
# ['@dotcalmu @realdonaldtrump you shouldn’t body shame remember?', 'gillette and all the other liberal bs y’all spout.']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['"it\'s only by challenging ourselves to do more that we can get closer to our best" @proctergamble ‘s @gillette is t']
# ['@cammml6 @gillette actually internet shave club was a generic reference not meant to imply harry’s, dollar, etc.', 'tr']
# ['@tentaclesama7 @gillette at the risk of tying you down to specifics, what behaviour in the add was toxic masculinit']
# ['@goz_1911 @gillette to funny']
# ['rt @charliepick: “it’s not easy being tough” - i think someone needs to watch a gillette commercial']
# ['@josh_hammer @axe  @speedstick  @dove  @gillette  @oldspice  @secretdeodorant  you’re all part of a conservative sm']
# ['rt @h0n3y_73: #foxnews sponsors.', 'they are tagged so they will be notified for each like/retweet/comment  @keurig @nestle @oldspice @olays']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @isomorphisms: camden after the fall howard gillette, jr.']
# ['gillette: the worst an ad can get |   via @youtube']
# ["rt @takedownmras: warwick marsh, the men's rights activist who didn't want gay men to be able marry / thinks conversion therapy works, not"]
# ['yes i know gillette also wanted profit.', 'this is also not an exhaustive list.', 'but it is exhausting just thinking about it.']
# ['@heartel24 @inc @dakotashane_nun @gillette by portraying play fighting as a bad thing.', 'by portraying chatting up wo']
# ["@wadepearson wade, we are so sorry that your message wasn't responded to by our customer care.", 'please call 1-800-44']
# ["rt @inc: here's how to avoid being the next gillette or pepsi in 2019 @dakotashane_nun"]
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['@thecw is masculinity toxic?', '(re: gillette)  via @youtube']
# ['rt @misandry_kills: #crimebywomen #fraudbywomen  #elizabethholmes  #womenempowerment #womensmarch2019  #thebestwomencanbe @gillette  story']
# ['rt @designationnine: these are @foxnews sponsors.they are tagged so they will be notified for each like/retweet/comment @oralb @gorving @pf']
# ['handmade razor shaving kit mach 3 shaving handle gillette mach 3 razor.', 'black and white ebony handle chrome hardwar']
# ['rt @spidervesre: this is how you use your brand.', 'this is how you engage with your audience.', 'gillette being aware of mostly having a male au']
# ['rt @gyakutennomeg: two little boys roughhousing?', 'labeled "toxic masculinity" by gillette.', 'little black girl punching a little white boy in']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['the gillette ad']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ["@leffinlaguna @evaninthebay @keithboykin @cnn it's like that gillette commercial."]
# ['@inc @dakotashane_nun how was @gillette ‘s ad out-of-touch with the general public?']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ["@sethcotlar those poor folks need to shave with gillette as i hear it's amazing on sensitive skin."]
# ['rt @mikereiss: when the krafts raised the gillette stadium sign two years ago to make room for a 5th super bowl banner, they had the foresi']
# ['@ajoatsvall @ag_conservative @david_boaz your right and the only difference this time is that instead of men leadin']
# ['@barstoolsports @gillette  come get your girl']
# ['rt @designationsix: here are some fox news sponsors.', 'they are tagged in the comments so they will be notified for each like retweet or comm']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ["rt @inc: here's how to avoid being the next gillette or pepsi in 2019 @dakotashane_nun"]
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @h0n3y_73: #foxnews sponsors.', 'they are tagged so they will be notified for each like/retweet/comment  @keurig @nestle @oldspice @olays']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ["here's how to avoid being the next gillette or pepsi in 2019 dakotashane_nun"]
# ['rt @ohnoshetwitnt: ads for women: be thin, be thick, love your body, your boobs look bigger in this, dye your hair, embrace your grays, the']
# ["rt @inc: here's how to avoid being the next gillette or pepsi in 2019 @dakotashane_nun"]
# ["here's how to avoid being the next gillette or pepsi in 2019 dakotashane_nun"]
# ['rt @jody_mazzarese: #egardwatches @egardwatchco in response to #gillettead this needs to go viral ... we know gillette is full of crap, but']
# ['rt @designationsix: these are @foxnews sponsors.', 'they are tagged so they will be notified for each like/retweet/comment @keurig @nestle @ol']
# ['the top body razor pick in our guide to the best drugstore makeup, hair, and skincare products, the gillette venus']
# ["here's how to avoid being the next gillette or pepsi in 2019 dakotashane_nun"]
# ['@gillette on jan 15th i sent a message to your customer care.', 'i was promised a response.', "still haven't heard a th"]
# ['rt @designationsix: these are @foxnews sponsors.', 'they are tagged so they will be notified for each like/retweet/comment @keurig @nestle @ol']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ["here's how to avoid being the next gillette or pepsi in 2019 @dakotashane_nun"]
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @seconds_0ut: gillette release an alternative ad...']
# ['rt @h0n3y_73: #foxnews sponsors.', 'they are tagged so they will be notified for each like/retweet/comment  @keurig @nestle @oldspice @olays']
# ['rt @h0n3y_73: #foxnews sponsors.', 'they are tagged so they will be notified for each like/retweet/comment  @keurig @nestle @oldspice @olays']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @gyakutennomeg: two little boys roughhousing?', 'labeled "toxic masculinity" by gillette.', 'little black girl punching a little white boy in']
# ['@charliejlfitz i’ve been researching dr. gillette in barcelona.', 'is that who you saw?']
# ['rt @oooijamesiooo: @rt_com gillette has started a popular trend.']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @jermynrichard: @titaniamcgrath is she boycotting gillette?', 'in that case i am on board 100%']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['@paul_serran viva la france #wwg1wgaworldwide #letsqthis #gr8awakening #gr8qwikening4jesus gillette ought to tape s']
# ['oregon district wins again...']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['rt @emilyjashinsky: this message brought to you by gillette.']
# ['@gillette wow, gotta say, i’m triggered.', 'my souls can not fathom how happy i am with this.', 'wow, just wow.', 'i love t']
# ['rt @designationsix: these are @foxnews sponsors.', 'they are tagged so they will be notified for each like/retweet/comment @keurig @nestle @ol']
# ['rt @obianuju: little brother rushes in to “save” his big sis.', 'very very cute!', 'the first time i saw this i wanted to say “boys will be boy']
# ['i wish @charli_xcx could’ve performed 1999 at the gillette shows cause that song slaps']

# %%
#and here, since some people have mispelled gilette
search = api.GetSearch("#gilette", lang='en', count=200)
for t in search:
    tweets = t.text.lower()
    tweets = re.sub(r"http\S+", "", tweets)
    tweets = tweets.replace("…","")
    tweets = strip_emoji(tweets)
    sentences = sent_tokenize(tweets.replace('\n',' '))
    clean_words = [word for word in sentences if word not in set(string.punctuation)]
    characters_to_remove = ["''",'``','...']
    clean_words = [word for word in clean_words if word not in set(characters_to_remove)]
    characters_to_remove2 = [word for word in clean_words if any(letter in sentences for letter in '\\')]
    clean_words = [word for word in clean_words if word not in set(characters_to_remove2)]
    print(clean_words)
# Out:
# ['@titaniamcgrath where is a #gilette when you need one.']
# ['if  @gillette had said  this  ,  this way ... the backslash  were  no where  near the one']
# ['rt @chandana_hiran: @kapoors_s @karanjohar @katja_iversen @wef @sayftycom .', '@karanjohar i really appreciate that you addressed objectificati']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['@judeochretiens is this the best the women can get ?', '#gilette #boycottgilette #feminism']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['should #gilette even be allowed to still sponsor #soccersaturday given that they clearly hate men so much nowadays?']
# ['#gilette now using a disabled african american guy for their commercial.', 'can they possibly try any harder to pander']
# ['about that total shit #gilette "commercial" #feminism #proctorgamble']
# ['diane lane is so much more interesting banging that painter in ‘unfaithful’ than she is in ‘house of cards’ on .', '@netflix #gilette']
# ['looks like #reebok and #gilette are 100% communists.', 'their advertising are so leftist that #lenin would buy both.', 'i']
# ['@rtsportnews @rt_com @adidasus &amp; @gillette can go fuck themselves #gilette #gillettead #adidas #bullshit']
# ['@vnbateman  you need to be in a #gilette commercial.']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['@tariqnasheed #toxicmasculinity "they/them/thou/thoust" need to shave with #gilette']
# ['@bluesea1964 @billrochdayle she should be in the next #gilette ad, no really shaving that gash']
# ['rt @55_ndrsglr: well #soyboy walking #gilette ad beta o’rourke just climbed up the intersectionality ladder.', 'kamala better watch out .', 'htt']
# ['thanks #gilette for making this meme possible lol']
# ['rt @55_ndrsglr: well #soyboy walking #gilette ad beta o’rourke just climbed up the intersectionality ladder.', 'kamala better watch out .', 'htt']
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ['how is this a thing?', '6th of february 2019 - youtube   #bitchute #indygogo #limitedstate']
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ['still thinking of the guy who kept interrupting a speaker last night to say how not bothered he was about his male']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['@rainingcrow im just so grateful to have a billion dollar corporation make an ad to let me know how shitty my gende']
# ["@vnbateman @eucopresident #gilette.....don't leave home without them..."]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ['rt @newsbreak123: masculinity is not under attack.', "what's under attack is men who are sexist, misogynistic or even downright dangerous to o"]
# ['rt @newsbreak123: masculinity is not under attack.', "what's under attack is men who are sexist, misogynistic or even downright dangerous to o"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['@proudresister i bet the #gilette commercial really got to him!']
# ['@vnbateman @eucopresident i hate porn from the 70s.', '#gilette']
# ['not the best a man can get #gilette']
# ['so, just seeing the #gilette commercial.', '#applause #newcustomer #boys #men']
# ['well #soyboy walking #gilette ad beta o’rourke just climbed up the intersectionality ladder.', 'kamala better watch ou']
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ['great girls trip...in about 36 hours we traveled back and forth through 7 states, watched a parade, shopped and of']
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ["rt @ritamitsuko: men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ['@thatbuffaloman very true.', 'they are boys.', "they're probably just salty that a female streamer has more views than th"]
# ["men: we don't need #gilette to tell us how to be better human beings   also men:"]
# ['rt @mzansi_hookups1: who wants some milkshake.', 'northern cape boys got cum for africa   #decorartehogar #10yearchallenge #2008vs2018 #2']
# ['rt @anjastas: congrats #gilette showing us how brands can positively influence the social narrative!!', '#purposefulmarketing #meaningfulmarke']
# ['new date screening question: "so, what did you think about the #gilette ad?"', '️\u200d♀️']
# ['finally got around to listening to that new james blake.', 'jesus fucking christ #realman #gilette']
# ['does this remind anyone of the #gilette ad from last month?', '#marketoon #advertising #digitalmarketing']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['@sdbcraig we have not hired gavin.', 'we have hired his brother miles.', 'and as a male feminist, zhe has requested that']
# ['i love white men, #gilette calls on all men to review their behaviour- lose their  neeson wants to kill black ppl-']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ['of course not, why should it at hurt them in the first place.', 'controversy is just a great way to catch your attenti']
# ['rt @realcandaceo: i just hope #gilette makes an ad reminding women not to fake their sexual assaults.', 'really important we be reminded not']
# ["i got these #gilette razors, because if they're good enough for your face, they're good enough for my legs."]
# ['get mad, get angry.', 'forget the #superbowl, forget #gilette,.', 'focus on real issues.', 'people are dying because canada']
# ['rt @carlwbz: .', '@superbowl champs @pats_superbowl are home.', '#gilette #foxboro #wbz']
# ['"#gilette had a strong ad, powerful message, why wasn\'t it featured during the #superbowl?"', '-nina orezzoli #adbowl #boyswillbeboys']
# ['rt @carlwbz: .', '@superbowl champs @pats_superbowl are home.', '#gilette #foxboro #wbz']
# ['rt @carlwbz: .', '@superbowl champs @pats_superbowl are home.', '#gilette #foxboro #wbz']
# ['rt @carlwbz: .', '@superbowl champs @pats_superbowl are home.', '#gilette #foxboro #wbz']
# ['@superbowl champs @pats_superbowl are home.', '#gilette #foxboro #wbz']
# ["...suck my dick 3rd wave #feminists and #sjw 's embracing the #gilette #virtuesignalling #normies with the most str"]
# ['@3yearletterman @ava @nfl @kaepernick7 @proctergamble #gilette aunt happy with you']
# ['and i hope #gilette stadium and everything it contains falls into dust.', '#gilette thinks any man is toxic - they sh']
# ['@idukewhatiwant @tomilahren you better go buy your #gilette razors right now.']
# ['#wishmymomtoldme men’s razors work way better than women’s razors.', 'they also tend to be cheaper and better quality.']
# ['rt @vfinch: i hope nike does another kneeling moron commercial for the #superbowl followed by the #gilette ad.']
# ['i hope nike does another kneeling moron commercial for the #superbowl followed by the #gilette ad.']
# ['rt @claire_lee: dear men offended by the #gilette advert...  1) put your ego aside for 1 second and realise that not everything is about yo']
# ['“what we’ve seen from the #metoo and #timesup movements is that toxic masculinity is far more prevalent than most m']
# ['bullying a boy that does ballet is part of the toxic masculinity #gilette had an ad against.']

# %%
#another slogan attached to the campaign
search = api.GetSearch("thebestamancanget", lang='en', count=200)
for t in search:
    tweets = t.text.lower()
    tweets = re.sub(r"http\S+", "", tweets)
    tweets = tweets.replace("…","")
    tweets = strip_emoji(tweets)
    sentences = sent_tokenize(tweets.replace('\n',' '))
    clean_words = [word for word in sentences if word not in set(string.punctuation)]
    characters_to_remove = ["''",'``','...']
    clean_words = [word for word in clean_words if word not in set(characters_to_remove)]
    characters_to_remove2 = [word for word in clean_words if any(letter in sentences for letter in '\\')]
    clean_words = [word for word in clean_words if word not in set(characters_to_remove2)]
    print(clean_words)
# Out:
# ['my lad preparing for a smooth transition into adulthood.', '@gillette #1stshave  #thebestamancanget']
# ['rt @sneville15: hey boys club - it’s not ok to find humour in terms derogatory towards women, it’s revolting!', 'how about standing up for wha']
# ['hey boys club - it’s not ok to find humour in terms derogatory towards women, it’s revolting!', 'how about standing up']
# ['new video is up!!', 'was the gillette ad nasty or necessary?', 'why are opinions so divided?', "here's what i think!"]
# ['rt @redeemervip: this man should be ashamed #gillette #thebestamancanget #metalgearsolidvthephantompain #xboxshare']
# ["@cheese_kun89 woah bro, rape's not cool.", '#thebestamancanget']
# ['#tbt“the best a man can get” original gillette commercial (1989)  #atari #videogamecollection #classicgaming #nes']
# ["rt @b2bcopychat: time for q2: more and more brands are getting political and taking a stand - we all remember @gillette's #thebestamancange"]
# ["time for q2: more and more brands are getting political and taking a stand - we all remember @gillette's"]
# ["@mascundone why not talk about masculinity and culture change with the men who attend the men's groups you've gone"]
# ['let’s change the narrative!', 'what’s your experience with men stepping up?', '#gillette #thebestamancanget #masculinity']
# ['rt @elizabethann028: days ago, we were celebrating the #gillettead for holding men accountable for their actions.', 'this included diminishing']
# ["this week's #blog takes a look at the recent @gillette #ad &amp; questions its success &amp; its motives.", 'is it still']
# ['gotta love the hipocracy of virtue signaling gillette: #boycottgillette #thebestmencanbe  #thebestamaamcanget']
# ['so i literally just watched the gillette commercial and i legit almost cried!', 'i love the message!', '#nomoremisogyny #thebestamancanget']
# ['@paulm1430 no it was you admitting you were a red all along.', 'i admire that #thebestamancanget']
# ["monday's motivation ✊ gents, let's always be, no matter what, the gentlemen we've been thought and grown up 2 b"]
# ['hey gillette take notes.', '#thebestamancanget #boycottgillette #realmen']
# ['a bloke in the shop came up to me and congratulated me for not buying #gillette.', 'then a friend sent me a text becau']
# ['rt @jsmbodywork: @angie_harmon @gillette @brooklyndecker compare @gillette 2018 pc “#thebestamancanbe” vs. its 1989 “#thebestamancanget” be']
# ['@angie_harmon @gillette @brooklyndecker compare @gillette 2018 pc “#thebestamancanbe” vs. its 1989 “']
# ['rt @jannawilkinso69:  a #juicy little #morsel for all you #soyboy #cucks out there !!', '#thebestamancanget ????????????????????????']

# %%
# Our cleaning function isn't perfect because we did not tokenize
#the tweets into words, seperating them, where we could've better deleted the rts and the @s. But generally this is one approach,
#and could be further modified, exported into csv, and cleaned up further in Excel
